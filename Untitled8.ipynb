# %%
array = ["水","金","地","火","木","土","天","海","冥"]
i=0

for i in range(2):
  if i == 0:
    for a in array:
      print(a)
  else:
    for a in array:
      print(" "+a)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
#  水
#  金
#  地
#  火
#  木
#  土
#  天
#  海
#  冥

# %%
array = ["水","金","地","火","木","土","天","海","冥"]
x = 0
i = 0
while i < 2:
  x = 0
  if i == 0:
    while x < 9:
      print(array[x])
      x = x + 1
  else:
    while x < 9:
      print(f" {array[x]}")
      x = x + 1
  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
#  水
#  金
#  地
#  火
#  木
#  土
#  天
#  海
#  冥
