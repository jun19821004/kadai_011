# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for i in range(2):
  if i == 0:
    for a in array:
      print(a)

  else:
    for a in array:
      print(" " + a)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
#  水
#  金
#  地
#  火
#  木
#  土
#  天
#  海
#  冥

# %%
array = ["水","金","地","火","木","土","天","海","冥"]
i = 0
while  i < 2:
  if i == 0:
    for a in array:
      print(a)

  else:
    for a in array:
      print(" " + a)

  i = i + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
#  水
#  金
#  地
#  火
#  木
#  土
#  天
#  海
#  冥

# %%
array = ["水","金","地","火","木","土","天","海","冥"]
i=0

for i in range(2):
  if i == 0:
    for a in array:
      print(a)
  else:
    for a in array:
      print(" "+a)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
#  水
#  金
#  地
#  火
#  木
#  土
#  天
#  海
#  冥

# %%
array = ["水","金","地","火","木","土","天","海","冥"]
i=0

while i < 2:
  if i == 0:
    for a in array:
      print(a)
  else:
    for a in array:
      print(" "+a)
  i = i+1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
#  水
#  金
#  地
#  火
#  木
#  土
#  天
#  海
#  冥
